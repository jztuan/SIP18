# %%
## set paths to catalog/script files and output directories (for plots)
data_dir = '../hdf5files/'
script_dir = '../SIP_jerome_scripts2/'
out_dir = './'

# %%
## load plotting routines
execfile(script_dir+'plot_routines.py')

# %%
gds = Table.read(data_dir+'gds.hdf5')
# Out:
# /Users/Andy/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# WARNING: path= was not specified but multiple tables are present, reading in first available table (path=data) [astropy.io.misc.hdf5]

# %%
gds_selection = np.where ( \
                          (gds['PhotFlag']==0) &\
                         (gds['ACS_F606W_FLUX'] > 0) &\
                         (gds['ACS_F814W_FLUX'] > 0) &\
                         (gds['WFC3_F125W_FLUX'] > 0))
# last 3 conditions ensure log10() exists

# %%
gds_final = gds[gds_selection]

# %%
## define variables for GOODS-S

f606_gds_flux = gds_final['ACS_F606W_FLUX']  ## rest-frame .606 μm magnitude
f814_gds_flux = gds_final['ACS_F814W_FLUX']   ## rest-frame .814 μm magnitude
f125_gds_flux = gds_final['WFC3_F125W_FLUX']   ## rest-frame 1.60 μm magnitude

f606_gds_mag = -2.5*np.log10(f606_gds_flux)
f814_gds_mag = -2.5*np.log10(f814_gds_flux)
f125_gds_mag = -2.5*np.log10(f125_gds_flux)

f606_f814_gds = f606_gds_mag - f814_gds_mag
f814_f125_gds = f814_gds_mag - f125_gds_mag

mstar_gds = gds_final['M_med'] # already logged?
z_gds = gds_final['z_best']  ## redshift

# %%
egs = Table.read(data_dir+'egs.hdf5')
# Out:
# WARNING: path= was not specified but multiple tables are present, reading in first available table (path=data) [astropy.io.misc.hdf5]

# %%
egs_selection = np.where ( \
                          (egs['PhotFlag']==0) &\
                         (egs['ACS_F606W_flux'] > 0) &\
                         (egs['ACS_F814W_flux'] > 0) &\
                         (egs['WFC3_F125W_flux'] > 0))
# last 3 conditions ensure log10() exists

# %%
egs_final = egs[egs_selection]

# %%
f606_egs_flux = egs_final['ACS_F606W_flux']  ## rest-frame .606 μm magnitude
f814_egs_flux = egs_final['ACS_F814W_flux']   ## rest-frame .814 μm magnitude
f125_egs_flux = egs_final['WFC3_F125W_flux']   ## rest-frame 1.60 μm magnitude

f606_egs_mag = -2.5*np.log10(f606_egs_flux)
f814_egs_mag = -2.5*np.log10(f814_egs_flux)
f125_egs_mag = -2.5*np.log10(f125_egs_flux)

f606_f814_egs = f606_egs_mag - f814_egs_mag
f814_f125_egs = f814_egs_mag - f125_egs_mag

mstar_egs = egs_final['M_med'] # already logged?
z_egs = egs_final['z_best']  ## redshift

# %%
gdn = Table.read(data_dir+'gdn.hdf5')
# Out:
# WARNING: path= was not specified but multiple tables are present, reading in first available table (path=data) [astropy.io.misc.hdf5]

# %%
gdn_selection = np.where ( \
                          (gdn['PhotFlag']==0) &\
                         (gdn['ACS_F606W_FLUX'] > 0) &\
                         (gdn['ACS_F814W_FLUX'] > 0) &\
                         (gdn['WFC3_F125W_FLUX'] > 0))
# last 3 conditions ensure log10() exists

# %%
gdn_final = gdn[gdn_selection]
print[gdn[0]]
# Out:
# [<Row index=0>
#   ID  FLUX_MAX_F435W FLUX_MAX_F606W FLUX_MAX_F775W FLUX_MAX_F814W FLUX_MAX_F850LP FLUX_MAX_F098M FLUX_MAX_F105W FLUX_MAX_F125W FLUX_MAX_F160W FLUX_ISO_F435W FLUXERR_ISO_F435W FLUX_ISO_F606W FLUXERR_ISO_F606W FLUX_ISO_F775W FLUXERR_ISO_F775W FLUX_ISO_F814W FLUXERR_ISO_F814W FLUX_ISO_F850LP FLUXERR_ISO_F850LP FLUX_ISO_F098M FLUXERR_ISO_F098M FLUX_ISO_F105W FLUXERR_ISO_F105W FLUX_ISO_F125W FLUXERR_ISO_F125W FLUX_ISO_F160W FLUXERR_ISO_F160W FLUX_ISOCOR_F435W FLUXERR_ISOCOR_F435W FLUX_ISOCOR_F606W FLUXERR_ISOCOR_F606W FLUX_ISOCOR_F775W FLUXERR_ISOCOR_F775W FLUX_ISOCOR_F814W FLUXERR_ISOCOR_F814W FLUX_ISOCOR_F850LP FLUXERR_ISOCOR_F850LP FLUX_ISOCOR_F098M FLUXERR_ISOCOR_F098M FLUX_ISOCOR_F105W FLUXERR_ISOCOR_F105W FLUX_ISOCOR_F125W FLUXERR_ISOCOR_F125W FLUX_ISOCOR_F160W FLUXERR_ISOCOR_F160W FLUX_AUTO_F435W FLUXERR_AUTO_F435W FLUX_AUTO_F606W FLUXERR_AUTO_F606W FLUX_AUTO_F775W FLUXERR_AUTO_F775W FLUX_AUTO_F814W FLUXERR_AUTO_F814W FLUX_AUTO_F850LP FLUXERR_AUTO_F850LP FLUX_AUTO_F098M FLUXERR_AUTO_F098M FLUX_AUTO_F105W FLUXERR_AUTO_F105W FLUX_AUTO_F125W FLUXERR_AUTO_F125W FLUX_AUTO_F160W FLUXERR_AUTO_F160W FLUX_PETRO_F435W FLUXERR_PETRO_F435W FLUX_PETRO_F606W FLUXERR_PETRO_F606W FLUX_PETRO_F775W FLUXERR_PETRO_F775W FLUX_PETRO_F814W FLUXERR_PETRO_F814W FLUX_PETRO_F850LP FLUXERR_PETRO_F850LP FLUX_PETRO_F098M FLUXERR_PETRO_F098M FLUX_PETRO_F105W FLUXERR_PETRO_F105W FLUX_PETRO_F125W FLUXERR_PETRO_F125W FLUX_PETRO_F160W FLUXERR_PETRO_F160W FLUX_BEST_F435W FLUXERR_BEST_F435W FLUX_BEST_F606W FLUXERR_BEST_F606W FLUX_BEST_F775W FLUXERR_BEST_F775W FLUX_BEST_F814W FLUXERR_BEST_F814W FLUX_BEST_F850LP FLUXERR_BEST_F850LP FLUX_BEST_F098M FLUXERR_BEST_F098M FLUX_BEST_F105W FLUXERR_BEST_F105W FLUX_BEST_F125W FLUXERR_BEST_F125W FLUX_BEST_F160W FLUXERR_BEST_F160W FLUX_APER_1_F435W FLUXERR_APER_1_F435W FLUX_APER_1_F606W FLUXERR_APER_1_F606W FLUX_APER_1_F775W FLUXERR_APER_1_F775W FLUX_APER_1_F814W FLUXERR_APER_1_F814W FLUX_APER_1_F850LP FLUXERR_APER_1_F850LP FLUX_APER_1_F098M FLUXERR_APER_1_F098M FLUX_APER_1_F105W FLUXERR_APER_1_F105W FLUX_APER_1_F125W FLUXERR_APER_1_F125W FLUX_APER_1_F160W FLUXERR_APER_1_F160W FLUX_APER_2_F435W FLUXERR_APER_2_F435W FLUX_APER_2_F606W FLUXERR_APER_2_F606W FLUX_APER_2_F775W FLUXERR_APER_2_F775W FLUX_APER_2_F814W FLUXERR_APER_2_F814W FLUX_APER_2_F850LP FLUXERR_APER_2_F850LP FLUX_APER_2_F098M FLUXERR_APER_2_F098M FLUX_APER_2_F105W FLUXERR_APER_2_F105W FLUX_APER_2_F125W FLUXERR_APER_2_F125W FLUX_APER_2_F160W FLUXERR_APER_2_F160W FLUX_APER_3_F435W FLUXERR_APER_3_F435W FLUX_APER_3_F606W FLUXERR_APER_3_F606W FLUX_APER_3_F775W FLUXERR_APER_3_F775W FLUX_APER_3_F814W FLUXERR_APER_3_F814W FLUX_APER_3_F850LP FLUXERR_APER_3_F850LP FLUX_APER_3_F098M FLUXERR_APER_3_F098M FLUX_APER_3_F105W FLUXERR_APER_3_F105W FLUX_APER_3_F125W FLUXERR_APER_3_F125W FLUX_APER_3_F160W FLUXERR_APER_3_F160W FLUX_APER_4_F435W FLUXERR_APER_4_F435W FLUX_APER_4_F606W FLUXERR_APER_4_F606W FLUX_APER_4_F775W FLUXERR_APER_4_F775W FLUX_APER_4_F814W FLUXERR_APER_4_F814W FLUX_APER_4_F850LP FLUXERR_APER_4_F850LP FLUX_APER_4_F098M FLUXERR_APER_4_F098M FLUX_APER_4_F105W FLUXERR_APER_4_F105W FLUX_APER_4_F125W FLUXERR_APER_4_F125W FLUX_APER_4_F160W FLUXERR_APER_4_F160W FLUX_APER_5_F435W FLUXERR_APER_5_F435W FLUX_APER_5_F606W FLUXERR_APER_5_F606W FLUX_APER_5_F775W FLUXERR_APER_5_F775W FLUX_APER_5_F814W FLUXERR_APER_5_F814W FLUX_APER_5_F850LP FLUXERR_APER_5_F850LP FLUX_APER_5_F098M FLUXERR_APER_5_F098M FLUX_APER_5_F105W FLUXERR_APER_5_F105W FLUX_APER_5_F125W FLUXERR_APER_5_F125W FLUX_APER_5_F160W FLUXERR_APER_5_F160W FLUX_APER_6_F435W FLUXERR_APER_6_F435W FLUX_APER_6_F606W FLUXERR_APER_6_F606W FLUX_APER_6_F775W FLUXERR_APER_6_F775W FLUX_APER_6_F814W FLUXERR_APER_6_F814W FLUX_APER_6_F850LP FLUXERR_APER_6_F850LP FLUX_APER_6_F098M FLUXERR_APER_6_F098M FLUX_APER_6_F105W FLUXERR_APER_6_F105W FLUX_APER_6_F125W FLUXERR_APER_6_F125W FLUX_APER_6_F160W FLUXERR_APER_6_F160W FLUX_APER_7_F435W FLUXERR_APER_7_F435W FLUX_APER_7_F606W FLUXERR_APER_7_F606W FLUX_APER_7_F775W FLUXERR_APER_7_F775W FL ...
# int64    float64        float64        float64        float64         float64        float64        float64        float64        float64        float64          float64         float64          float64         float64          float64         float64          float64          float64          float64          float64          float64         float64          float64         float64          float64         float64          float64           float64            float64             float64            float64             float64            float64             float64            float64             float64              float64             float64            float64             float64            float64             float64            float64             float64            float64            float64          float64           float64          float64           float64          float64           float64          float64           float64            float64           float64          float64           float64          float64           float64          float64           float64          float64           float64            float64           float64            float64           float64            float64           float64            float64            float64            float64            float64            float64           float64            float64           float64            float64           float64            float64           float64          float64           float64          float64           float64          float64           float64          float64           float64            float64           float64          float64           float64          float64           float64          float64           float64          float64            float64            float64             float64            float64             float64            float64             float64            float64             float64              float64             float64            float64             float64            float64             float64            float64             float64            float64             float64            float64             float64            float64             float64            float64             float64            float64             float64              float64             float64            float64             float64            float64             float64            float64             float64            float64             float64            float64             float64            float64             float64            float64             float64            float64             float64              float64             float64            float64             float64            float64             float64            float64             float64            float64             float64            float64             float64            float64             float64            float64             float64            float64             float64              float64             float64            float64             float64            float64             float64            float64             float64            float64             float64            float64             float64            float64             float64            float64             float64            float64             float64              float64             float64            float64             float64            float64             float64            float64             float64            float64             float64            float64             float64            float64             float64            float64             float64            float64             float64              float64             float64            float64             float64            float64             float64            float64             float64            float64             float64            float64             float64            float64             float64            float64           ...
# ----- -------------- -------------- -------------- -------------- --------------- -------------- -------------- -------------- -------------- -------------- ----------------- -------------- ----------------- -------------- ----------------- -------------- ----------------- --------------- ------------------ -------------- ----------------- -------------- ----------------- -------------- ----------------- -------------- ----------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ------------------ --------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- --------------- ------------------ --------------- ------------------ --------------- ------------------ --------------- ------------------ ---------------- ------------------- --------------- ------------------ --------------- ------------------ --------------- ------------------ --------------- ------------------ ---------------- ------------------- ---------------- ------------------- ---------------- ------------------- ---------------- ------------------- ----------------- -------------------- ---------------- ------------------- ---------------- ------------------- ---------------- ------------------- ---------------- ------------------- --------------- ------------------ --------------- ------------------ --------------- ------------------ --------------- ------------------ ---------------- ------------------- --------------- ------------------ --------------- ------------------ --------------- ------------------ --------------- ------------------ ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ------------------ --------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ------------------ --------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ------------------ --------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ------------------ --------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ------------------ --------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ------------------ --------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- ----------------- -------------------- -- ...
#     1    0.000716588     0.00362408     0.00374889    0.000149877     0.000897309     0.00721282      0.0042701   -5.42608e-07      0.0679686     -0.0209892         0.0210274     -0.0235037          0.056286      0.0244224         0.0400913   -0.000927543     57445600000.0      -0.0261137          0.0244462      -0.094757         0.0648468     0.00684971         0.0393932   -3.10634e-05     57445600000.0       0.657798         0.0938223        -0.0472744            0.0929925          0.259353             0.237813           0.34919             0.172122          0.150051                  0.0          0.0121631              0.106222           1.31698             0.298483          0.462873             0.167587         0.0309195                  0.0             4.878               2.5313      0.00585745           0.116571        0.452282           0.297926        0.527807           0.215675           0.235                0.0         0.189423            0.133131         2.26306           0.374658        0.818203           0.211421       0.0484239                0.0         6.67262            2.56137       -0.0472744           0.0929925         0.259353            0.237813          0.34919            0.172122     -0.000927543       57445600000.0         0.0121631             0.106222          1.31698            0.298483         0.462873            0.167587     -3.10634e-05       57445600000.0         0.657798           0.0938223     -0.00100466         0.00497776     -0.00100078          0.0136716     0.000838637         0.00925269     0.000425952                0.0      -0.00202792          0.00571554      0.00196255          0.0152966      0.00248038         0.00954111     8.77715e-05                0.0          0.0487          0.0258117       -0.00221547             0.006863       -0.00149047            0.0185911         0.0022389            0.0127716       0.000822861                  0.0        -0.00346861             0.0079546        0.00081488             0.020889        0.00470049            0.0131631       0.000169559                  0.0          0.090722            0.0355373       -0.00477943           0.00958189       -0.00220455            0.0258833        0.00579053            0.0180106        0.00162636                  0.0        -0.00567235             0.0110878       -0.00583396             0.029315         0.0090994            0.0181896       0.000335128                  0.0          0.175609            0.0474395        -0.0104297            0.0134774       -0.00128147            0.0363335         0.0155668            0.0253453        0.00325272                  0.0         -0.0084768             0.0156968        -0.0297009            0.0416904         0.0127899            0.0257098       0.000670255                  0.0          0.335451            0.0642939        -0.0201618            0.0191487        -0.0088635            0.0515677         0.0255855            0.0363851        0.00659257                  0.0         -0.0143571             0.0223489        -0.0729822             0.060967        0.00786276            0.0357904        0.00135846                  0.0          0.585063            0.0881814        -0.0295179            0.0272343         -0.029394            0.0721467         0.0138552            0.0517622         0.0132723                  0.0         -0.0354302             0.0315281        -0.0515568            0.0885364        -0.0149101            0.0504947        0.00273488                  0.0           0.87976             0.120791        -0.0377459            0.0385299         -0.017319             0.101025        0.00595972            0.0729056         0.0263703                  0.0         -0.0670101             0.0445574          0.076159             0.125228       -0.00497495            0.0706594        0.00543385                  0.0           1.26758             0.167923        -0.0573151            0.0550036        -0.0179679             0.141328         0.0604727             0.102639    ...

# %%
## define variables for GOODS-S

f606_gdn_flux = gdn_final['ACS_F606W_FLUX']  ## rest-frame .606 μm magnitude
f814_gdn_flux = gdn_final['ACS_F814W_FLUX']   ## rest-frame .814 μm magnitude
f125_gdn_flux = gdn_final['WFC3_F125W_FLUX']   ## rest-frame 1.60 μm magnitude

f606_gdn_mag = -2.5*np.log10(f606_gdn_flux)
f814_gdn_mag = -2.5*np.log10(f814_gdn_flux)
f125_gdn_mag = -2.5*np.log10(f125_gdn_flux)

f606_f814_gdn = f606_gdn_mag - f814_gdn_mag
f814_f125_gdn = f814_gdn_mag - f125_gdn_mag

mstar_gdn = gdn_final['M_med'] # already logged?
z_gdn = gdn_final['z_best_1']  ## redshift

# %%
cos = Table.read(data_dir+'cos.hdf5')
# Out:
# WARNING: path= was not specified but multiple tables are present, reading in first available table (path=data) [astropy.io.misc.hdf5]

# %%
cos_selection = np.where ( \
                          (cos['PhotFlag']==0) &\
                         (cos['ACS_F606W_FLUX'] > 0) &\
                         (cos['ACS_F814W_FLUX'] > 0) &\
                         (cos['WFC3_F125W_FLUX'] > 0))
# last 3 conditions ensure log10() exists

# %%
cos_final = cos[cos_selection]

# %%
f606_cos_flux = cos_final['ACS_F606W_FLUX']  ## rest-frame .606 μm magnitude
f814_cos_flux = cos_final['ACS_F814W_FLUX']   ## rest-frame .814 μm magnitude
f125_cos_flux = cos_final['WFC3_F125W_FLUX']   ## rest-frame 1.25 μm magnitude

f606_cos_mag = -2.5*np.log10(f606_cos_flux)
f814_cos_mag = -2.5*np.log10(f814_cos_flux)
f125_cos_mag = -2.5*np.log10(f125_cos_flux)

f606_f814_cos = f606_cos_mag - f814_cos_mag
f814_f125_cos = f814_cos_mag - f125_cos_mag

mstar_cos = cos_final['M_med'] # already logged?
z_cos = cos_final['z_best']  ## redshift

# %%
f606_f814 = np.concatenate([f606_f814_gds,f606_f814_egs,f606_f814_gdn,f606_f814_cos])
f814_f125 = np.concatenate([f814_f125_gds,f814_f125_egs,f814_f125_gdn,f814_f125_cos])
mass = np.concatenate([mstar_gds,mstar_egs])
redshift = np.concatenate([z_gds,z_egs])

# %%
fig=plt.figure(figsize=(8,8))
plt.scatter(f606_f814,f814_f125,c='gray',edgecolors='none',s=8,alpha=0.7)
plt.xlim(-0.25,2.5)
plt.ylim(0,2.2)
plt.xlabel('.814micron-1.25micron')
plt.ylabel('.606micron-.814micron')
plt.savefig('/Users/Andy/Desktop/test1.pdf')

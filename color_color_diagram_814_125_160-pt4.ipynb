# %%
## set paths to catalog/script files and output directories (for plots)
data_dir = '../hdf5files/'
script_dir = '../SIP_jerome_scripts2/'
out_dir = './'

# %%
## load plotting routines
execfile(script_dir+'plot_routines.py')

# %%
gds = Table.read(data_dir+'gds.hdf5')
# Out:
# /Users/Andy/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# WARNING: path= was not specified but multiple tables are present, reading in first available table (path=data) [astropy.io.misc.hdf5]

# %%
gds_selection = np.where ( \
                          (gds['PhotFlag']==0) &\
                          (gds['CLASS_STAR']>0.9) & \
                         (gds['ACS_F814W_FLUX'] > 0) &\
                          (gds['WFC3_F125W_FLUX'] > 0) &\
                         (gds['WFC3_F160W_FLUX'] > 0))

# last 3 conditions ensure log10() exists

# %%
gds_temp = gds[gds_selection]
gds_selection2 = np.where ( \
                          -2.5*np.log10(gds_temp['WFC3_F125W_FLUX']) <= 1.359465)
gds_final = gds_temp[gds_selection2]

# %%
## define variables for GOODS-S

f814_gds_flux = gds_final['ACS_F814W_FLUX']  ## rest-frame .814 μm magnitude
f125_gds_flux = gds_final['WFC3_F125W_FLUX']   ## rest-frame 1.25 μm magnitude
f160_gds_flux = gds_final['WFC3_F160W_FLUX']   ## rest-frame 1.60 μm magnitude

f814_gds_mag = -2.5*np.log10(f814_gds_flux)
f125_gds_mag = -2.5*np.log10(f125_gds_flux)
f160_gds_mag = -2.5*np.log10(f160_gds_flux)

f814_f125_gds = f814_gds_mag - f125_gds_mag
f125_f160_gds = f125_gds_mag - f160_gds_mag

mstar_gds = gds_final['M_med'] # already logged?
z_gds = gds_final['z_best']  ## redshift

# %%
egs = Table.read(data_dir+'egs.hdf5')
# Out:
# WARNING: path= was not specified but multiple tables are present, reading in first available table (path=data) [astropy.io.misc.hdf5]

# %%
egs_selection = np.where ( \
                          (egs['PhotFlag']==0) &\
                          (egs['CLASS_STAR']>0.9) & \
                         (egs['ACS_F814W_flux'] > 0) &\
                         (egs['WFC3_F125W_flux'] > 0) &\
                         (egs['WFC3_F160W_flux'] > 0))
# last 3 conditions ensure log10() exists

# %%
egs_temp = egs[egs_selection]
egs_selection2 = np.where ( \
                          -2.5*np.log10(egs_temp['WFC3_F125W_flux']) < 1.209293)
egs_final = egs_temp[egs_selection2]

# %%
f814_egs_flux = egs_final['ACS_F814W_flux']  ## rest-frame .814 μm magnitude
f125_egs_flux = egs_final['WFC3_F125W_flux']   ## rest-frame 1.25 μm magnitude
f160_egs_flux = egs_final['WFC3_F160W_flux']   ## rest-frame 1.60 μm magnitude

f814_egs_mag = -2.5*np.log10(f814_egs_flux)
f125_egs_mag = -2.5*np.log10(f125_egs_flux)
f160_egs_mag = -2.5*np.log10(f160_egs_flux)

f814_f125_egs = f814_egs_mag - f125_egs_mag
f125_f160_egs = f125_egs_mag - f160_egs_mag

mstar_egs = egs_final['M_med'] # already logged?
z_egs = egs_final['z_best']  ## redshift

# %%
gdn = Table.read(data_dir+'gdn.hdf5')
# Out:
# WARNING: path= was not specified but multiple tables are present, reading in first available table (path=data) [astropy.io.misc.hdf5]

# %%
gdn_selection = np.where ( \
                          (gdn['PhotFlag']==0) &\
                          (gdn['CLASS_STAR']>0.9) & \
                         (gdn['ACS_F814W_FLUX'] > 0) &\
                         (gdn['WFC3_F125W_FLUX'] > 0) &\
                         (gdn['WFC3_F160W_FLUX'] > 0))
# last 3 conditions ensure log10() exists

# %%
gdn_temp = gdn[gdn_selection]
gdn_selection2 = np.where ( \
                          -2.5*np.log10(gdn_temp['WFC3_F125W_FLUX']) <= 1.206120)
gdn_final = gdn_temp[gdn_selection2]
# print[gdn[0]]

# %%
## define variables for GOODS-S

f814_gdn_flux = gdn_final['ACS_F814W_FLUX']  ## rest-frame .814 μm magnitude
f125_gdn_flux = gdn_final['WFC3_F125W_FLUX']   ## rest-frame 1.25 μm magnitude
f160_gdn_flux = gdn_final['WFC3_F160W_FLUX']   ## rest-frame 1.60 μm magnitude

f814_gdn_mag = -2.5*np.log10(f814_gdn_flux)
f125_gdn_mag = -2.5*np.log10(f125_gdn_flux)
f160_gdn_mag = -2.5*np.log10(f160_gdn_flux)

f814_f125_gdn = f814_gdn_mag - f125_gdn_mag
f125_f160_gdn = f125_gdn_mag - f160_gdn_mag

mstar_gdn = gdn_final['M_med'] # already logged?
z_gdn = gdn_final['z_best_1']  ## redshift

# %%
cos = Table.read(data_dir+'cos.hdf5')
# Out:
# WARNING: path= was not specified but multiple tables are present, reading in first available table (path=data) [astropy.io.misc.hdf5]

# %%
cos_selection = np.where ( \
                          (cos['PhotFlag']==0) &\
                          (cos['CLASS_STAR']>0.9) & \
                         (cos['ACS_F814W_FLUX'] > 0) &\
                         (cos['WFC3_F125W_FLUX'] > 0) &\
                         (cos['WFC3_F160W_FLUX'] > 0))
# last 3 conditions ensure log10() exists

# %%
cos_temp = cos[cos_selection]
cos_selection2 = np.where ( \
                          -2.5*np.log10(cos_temp['WFC3_F125W_FLUX']) <= 1.026014)
cos_final = cos_temp[cos_selection2]

# %%
f814_cos_flux = cos_final['ACS_F814W_FLUX']  ## rest-frame .814 μm magnitude
f125_cos_flux = cos_final['WFC3_F125W_FLUX']   ## rest-frame 1.25 μm magnitude
f160_cos_flux = cos_final['WFC3_F160W_FLUX']   ## rest-frame 1.60 μm magnitude

f814_cos_mag = -2.5*np.log10(f814_cos_flux)
f125_cos_mag = -2.5*np.log10(f125_cos_flux)
f160_cos_mag = -2.5*np.log10(f160_cos_flux)

f814_f125_cos = f814_cos_mag - f125_cos_mag
f125_f160_cos = f125_cos_mag - f160_cos_mag

mstar_cos = cos_final['M_med'] # already logged?
z_cos = cos_final['z_best']  ## redshift

# %%
f814_f125 = np.concatenate([f814_f125_gds,f814_f125_egs,f814_f125_gdn,f814_f125_cos])
f125_f160 = np.concatenate([f125_f160_gds,f125_f160_egs,f125_f160_gdn,f125_f160_cos])
mass = np.concatenate([mstar_gds,mstar_egs])
redshift = np.concatenate([z_gds,z_egs])

# %%
fig=plt.figure(figsize=(8,8))
plt.scatter(f125_f160,f814_f125,c='gray',edgecolors='none',s=8,alpha=0.7)
plt.xlim(-0.5,4)
plt.ylim(-0.5,4)
plt.xlabel('J (1.25micron) - H (1.60micron)')
plt.ylabel('I (.814micron) - J (1.25micron)')
# plt.savefig('/Users/Andy/Desktop/IJH_pt4_all_galaxylike.pdf')
# Out:
# Text(0,0.5,'I (.814micron) - J (1.25micron)')

# %%
# fig=plt.figure(figsize=(8,8))
# plt.scatter(f125_f160_gds,f814_f125_gds,c='gray',edgecolors='none',s=8,alpha=0.7)
# plt.xlim(-0.5,4)
# plt.ylim(-0.5,4)
# plt.xlabel('J (1.25micron) - H (1.60micron)')
# plt.ylabel('I (.814micron) - J (1.25micron)')
# plt.savefig('/Users/Andy/Desktop/IJH_pt4_gds_starlike.pdf')

# %%
data = [x for _,x in sorted(zip(f814_f125,f125_f160))]
f814_f125 = np.sort(f814_f125)
movingmedian_f814_f125 = np.array([])
movingmedian_f125_f160 = np.array([])
for i in range (0,1000):
    data2 = np.array([])
    for j in range(i,i+15):
        data2 = np.append(data2,f814_f125[j])
    movingmedian_f814_f125 = np.append(movingmedian_f814_f125,np.median(data2))
for k in range (0,1000):
    data3 = np.array([])
    for l in range(k,k+15):
        data3 = np.append(data3,f125_f160[l])
    movingmedian_f125_f160 = np.append(movingmedian_f125_f160,np.median(data3))
print movingmedian_f814_f125
# Out:
# [-2.97799843e-01 -2.87377969e-01 -2.59099390e-01 -2.52300742e-01
#  -2.49197042e-01 -2.33300028e-01 -2.25399986e-01 -2.22104580e-01
#  -2.15301647e-01 -2.06241006e-01 -2.06094443e-01 -1.99297738e-01
#  -1.95396259e-01 -1.89800195e-01 -1.87342754e-01 -1.86438136e-01
#  -1.85113860e-01 -1.71899895e-01 -1.67785913e-01 -1.61349681e-01
#  -1.58249074e-01 -1.57578880e-01 -1.55000030e-01 -1.53372910e-01
#  -1.44833821e-01 -1.44500025e-01 -1.44314196e-01 -1.42197398e-01
#  -1.36782178e-01 -1.29432241e-01 -1.25536338e-01 -1.23199967e-01
#  -1.22329510e-01 -1.22000540e-01 -1.21444135e-01 -1.14819165e-01
#  -1.14700117e-01 -1.14400788e-01 -1.10526925e-01 -9.91396390e-02
#  -9.72000426e-02 -9.69186092e-02 -9.56736222e-02 -9.51319235e-02
#  -8.95044172e-02 -8.88245419e-02 -8.54994344e-02 -8.35829129e-02
#  -8.19999409e-02 -8.16966674e-02 -7.88641873e-02 -7.87539623e-02
#  -7.58999346e-02 -7.53034526e-02 -7.40434794e-02 -7.32708786e-02
#  -7.04258160e-02 -6.89211431e-02 -6.77011978e-02 -6.31468420e-02
#  -5.96143977e-02 -5.38357042e-02 -5.13721576e-02 -5.10213666e-02
#  -4.31474955e-02 -4.18999456e-02 -3.92000547e-02 -3.90862176e-02
#  -3.87998401e-02 -3.82195663e-02 -3.24497331e-02 -3.20872170e-02
#  -2.85975141e-02 -2.69214447e-02 -2.46319549e-02 -1.26476139e-02
#  -7.40762215e-03 -6.60480065e-03 -6.31098868e-03  1.33507218e-03
#   8.28027412e-03  9.08002401e-03  1.09985985e-02  1.24242495e-02
#   1.30810063e-02  1.80914740e-02  2.07998499e-02  2.17000141e-02
#   2.50165056e-02  2.53697916e-02  2.93830340e-02  3.35946595e-02
#   3.86463103e-02  3.95082432e-02  4.60005389e-02  4.66953171e-02
#   4.84904650e-02  4.87815845e-02  5.33999554e-02  5.58089972e-02
#   5.63291854e-02  5.73056824e-02  5.75985308e-02  5.82469645e-02
#   6.07977295e-02  6.17720359e-02  6.21831940e-02  6.38181599e-02
#   6.58526316e-02  8.01907584e-02  8.14836863e-02  8.25002029e-02
#   8.26069041e-02  8.27040003e-02  8.27991261e-02  8.35098925e-02
#   8.64529644e-02  8.69997880e-02  8.71101681e-02  8.86995142e-02
#   9.25429920e-02  9.25521382e-02  9.47663815e-02  9.79956348e-02
#   1.00397686e-01  1.03413316e-01  1.07971184e-01  1.10171208e-01
#   1.10709193e-01  1.11597943e-01  1.12602424e-01  1.14329736e-01
#   1.30000191e-01  1.32125523e-01  1.33085167e-01  1.34220660e-01
#   1.35557250e-01  1.38862524e-01  1.39574950e-01  1.39880015e-01
#   1.41824431e-01  1.42601676e-01  1.45101834e-01  1.47700598e-01
#   1.48857005e-01  1.50097392e-01  1.50600220e-01  1.53409959e-01
#   1.54099775e-01  1.58498391e-01  1.60381897e-01  1.66599794e-01
#   1.67109630e-01  1.70657386e-01  1.71405817e-01  1.74094705e-01
#   1.75800241e-01  1.79158662e-01  1.80770158e-01  1.83900357e-01
#   1.84474310e-01  1.85267502e-01  1.85321034e-01  1.91155107e-01
#   1.91993256e-01  1.94009270e-01  1.94229798e-01  1.95273246e-01
#   1.97107434e-01  1.98393960e-01  2.00711909e-01  2.03370861e-01
#   2.09645426e-01  2.09760480e-01  2.11752215e-01  2.15529950e-01
#   2.16348673e-01  2.16665023e-01  2.16945081e-01  2.17226918e-01
#   2.21036220e-01  2.22453331e-01  2.23802192e-01  2.24679237e-01
#   2.27920089e-01  2.28498000e-01  2.28914143e-01  2.29651100e-01
#   2.31718471e-01  2.32588766e-01  2.33008029e-01  2.35808072e-01
#   2.36053079e-01  2.39218336e-01  2.39433790e-01  2.40329821e-01
#   2.42697359e-01  2.45678791e-01  2.50900506e-01  2.51204710e-01
#   2.53122128e-01  2.54215217e-01  2.54715617e-01  2.56273763e-01
#   2.56329471e-01  2.62537389e-01  2.63591613e-01  2.65019554e-01
#   2.69012584e-01  2.71658472e-01  2.72999669e-01  2.73740063e-01
#   2.74752998e-01  2.76944311e-01  2.78429905e-01  2.82985523e-01
#   2.84591743e-01  2.84713887e-01  2.85896831e-01  2.88512325e-01
#   2.88968497e-01  2.90704947e-01  2.91015776e-01  2.91160060e-01
#   2.95899764e-01  2.96109598e-01  2.96599358e-01  2.96855789e-01
#   2.98817003e-01  2.99044540e-01  3.00451656e-01  3.02713313e-01
#   3.06020425e-01  3.07804329e-01  3.08098324e-01  3.08378193e-01
#   3.09799897e-01  3.11086131e-01  3.14399568e-01  3.16735033e-01
#   3.16920155e-01  3.18511676e-01  3.20379704e-01  3.21163090e-01
#   3.22709656e-01  3.23654647e-01  3.25759401e-01  3.25925129e-01
#   3.26707047e-01  3.30246735e-01  3.30996732e-01  3.31400092e-01
#   3.32540448e-01  3.32683589e-01  3.34671884e-01  3.35098689e-01
#   3.36408359e-01  3.37130812e-01  3.37180509e-01  3.37506884e-01
#   3.38603299e-01  3.38934316e-01  3.39709411e-01  3.40452640e-01
#   3.40639822e-01  3.43799930e-01  3.43996049e-01  3.46100001e-01
#   3.47182750e-01  3.47319648e-01  3.47744616e-01  3.47899169e-01
#   3.49309856e-01  3.49579206e-01  3.50665426e-01  3.50710267e-01
#   3.50979038e-01  3.51544669e-01  3.51780326e-01  3.54289840e-01
#   3.55873405e-01  3.59746367e-01  3.59768563e-01  3.59796931e-01
#   3.61400019e-01  3.61495500e-01  3.62199718e-01  3.63454104e-01
#   3.64184103e-01  3.65766790e-01  3.66383321e-01  3.67447210e-01
#   3.67477218e-01  3.68553588e-01  3.69408800e-01  3.70139187e-01
#   3.71404015e-01  3.71955423e-01  3.72200031e-01  3.72677022e-01
#   3.73889073e-01  3.74000345e-01  3.74310185e-01  3.75217542e-01
#   3.75446280e-01  3.77465200e-01  3.79574869e-01  3.80479164e-01
#   3.80832508e-01  3.81183967e-01  3.81600110e-01  3.81787889e-01
#   3.82598786e-01  3.82790431e-01  3.84900139e-01  3.85127898e-01
#   3.86996334e-01  3.88014384e-01  3.88100095e-01  3.88215017e-01
#   3.88570815e-01  3.88798528e-01  3.88864742e-01  3.89951093e-01
#   3.90267675e-01  3.90324787e-01  3.90988761e-01  3.91099988e-01
#   3.91564320e-01  3.91745545e-01  3.91804252e-01  3.92094715e-01
#   3.92367363e-01  3.92394801e-01  3.94223074e-01  3.94697510e-01
#   3.98680715e-01  3.99490487e-01  4.00200853e-01  4.00341096e-01
#   4.01294568e-01  4.01457720e-01  4.01615102e-01  4.02506258e-01
#   4.02790583e-01  4.06448252e-01  4.06499564e-01  4.06509284e-01
#   4.06761193e-01  4.06913924e-01  4.07627728e-01  4.09615282e-01
#   4.10599991e-01  4.10641764e-01  4.11416784e-01  4.11830160e-01
#   4.12753687e-01  4.15666230e-01  4.16577173e-01  4.17438596e-01
#   4.18384297e-01  4.18861927e-01  4.18936916e-01  4.19958595e-01
#   4.21899967e-01  4.21999767e-01  4.22291668e-01  4.22600108e-01
#   4.24249543e-01  4.25307856e-01  4.27050144e-01  4.27400478e-01
#   4.27790417e-01  4.28614418e-01  4.29033126e-01  4.29398752e-01
#   4.30904274e-01  4.31399132e-01  4.31456712e-01  4.32370810e-01
#   4.33073424e-01  4.36670314e-01  4.36853213e-01  4.37583772e-01
#   4.38105189e-01  4.38879760e-01  4.39261794e-01  4.39300439e-01
#   4.39799763e-01  4.40584272e-01  4.40989256e-01  4.41008910e-01
#   4.41073493e-01  4.41228761e-01  4.41408878e-01  4.41557633e-01
#   4.42573286e-01  4.43520664e-01  4.44076629e-01  4.45299930e-01
#   4.45699975e-01  4.46009325e-01  4.47499987e-01  4.47600707e-01
#   4.48425078e-01  4.48561969e-01  4.50002132e-01  4.50037816e-01
#   4.51626370e-01  4.52216570e-01  4.52572770e-01  4.53675208e-01
#   4.53959772e-01  4.54698926e-01  4.54714615e-01  4.54810597e-01
#   4.56299346e-01  4.56454986e-01  4.56732033e-01  4.56944320e-01
#   4.56997852e-01  4.57983987e-01  4.58159609e-01  4.58383703e-01
#   4.59398837e-01  4.61521068e-01  4.62705933e-01  4.62918173e-01
#   4.64541029e-01  4.64588233e-01  4.65432782e-01  4.66175926e-01
#   4.66901201e-01  4.67383413e-01  4.68178689e-01  4.68304943e-01
#   4.68850080e-01  4.69296035e-01  4.70197545e-01  4.72507804e-01
#   4.72806034e-01  4.73177757e-01  4.73731414e-01  4.73936675e-01
#   4.74665023e-01  4.74674841e-01  4.75060057e-01  4.75329250e-01
#   4.75434669e-01  4.76081302e-01  4.76662539e-01  4.77307903e-01
#   4.77510430e-01  4.79877942e-01  4.80186618e-01  4.81324255e-01
#   4.81963077e-01  4.83644142e-01  4.85599445e-01  4.86107079e-01
#   4.86306923e-01  4.86628914e-01  4.86735745e-01  4.87460062e-01
#   4.88045052e-01  4.88206853e-01  4.88730403e-01  4.88801083e-01
#   4.89238185e-01  4.89558550e-01  4.91913585e-01  4.92892844e-01
#   4.93389241e-01  4.94510308e-01  4.96603490e-01  4.97014649e-01
#   4.97441063e-01  4.98544439e-01  4.98697624e-01  4.99082802e-01
#   5.01505226e-01  5.01908355e-01  5.02186304e-01  5.02785983e-01
#   5.02917463e-01  5.04899797e-01  5.06744026e-01  5.07159141e-01
#   5.07213326e-01  5.08492786e-01  5.09644394e-01  5.10555372e-01
#   5.10734300e-01  5.10742384e-01  5.13929701e-01  5.14980998e-01
#   5.15905951e-01  5.15940563e-01  5.16704895e-01  5.16756762e-01
#   5.17285404e-01  5.17303285e-01  5.17458802e-01  5.19025259e-01
#   5.19100174e-01  5.20149234e-01  5.20310347e-01  5.21227714e-01
#   5.21894895e-01  5.22041494e-01  5.22768844e-01  5.23191449e-01
#   5.24099842e-01  5.24164901e-01  5.24167900e-01  5.24585304e-01
#   5.25579650e-01  5.25798312e-01  5.27857022e-01  5.28559520e-01
#   5.30704307e-01  5.30856475e-01  5.31013398e-01  5.31605051e-01
#   5.31889269e-01  5.32408838e-01  5.32808832e-01  5.34664936e-01
#   5.35012280e-01  5.35099892e-01  5.35227607e-01  5.38354285e-01
#   5.39350039e-01  5.39567126e-01  5.40192529e-01  5.40318857e-01
#   5.41141813e-01  5.41411775e-01  5.42000112e-01  5.42150145e-01
#   5.42385372e-01  5.42649508e-01  5.43400006e-01  5.44199984e-01
#   5.44652023e-01  5.45000061e-01  5.45999177e-01  5.50019308e-01
#   5.51029878e-01  5.52555210e-01  5.54336071e-01  5.54490496e-01
#   5.54514244e-01  5.54923606e-01  5.55068038e-01  5.56376539e-01
#   5.58254592e-01  5.58654665e-01  5.60482726e-01  5.60918885e-01
#   5.60933924e-01  5.61544419e-01  5.63116621e-01  5.63121175e-01
#   5.63794670e-01  5.64045507e-01  5.64586999e-01  5.64878242e-01
#   5.65299875e-01  5.67518619e-01  5.67609059e-01  5.68594605e-01
#   5.69609546e-01  5.70447452e-01  5.70827312e-01  5.74163752e-01
#   5.74857043e-01  5.75225913e-01  5.75364041e-01  5.75410312e-01
#   5.75427959e-01  5.76100138e-01  5.76191839e-01  5.77770957e-01
#   5.78133896e-01  5.78963798e-01  5.79505950e-01  5.79599436e-01
#   5.79878492e-01  5.81499996e-01  5.81822559e-01  5.81957190e-01
#   5.82594822e-01  5.83878033e-01  5.84648861e-01  5.85300811e-01
#   5.85605645e-01  5.87856290e-01  5.90726096e-01  5.93507075e-01
#   5.96844372e-01  5.97733412e-01  5.97869717e-01  5.97899479e-01
#   5.98173011e-01  6.00397190e-01  6.02299376e-01  6.02481743e-01
#   6.02701041e-01  6.03021774e-01  6.03115970e-01  6.05263190e-01
#   6.07192877e-01  6.08074356e-01  6.08313777e-01  6.09800038e-01
#   6.10852420e-01  6.11574358e-01  6.11631383e-01  6.12570368e-01
#   6.14300261e-01  6.14767117e-01  6.15687474e-01  6.15700042e-01
#   6.16897158e-01  6.19344664e-01  6.20733863e-01  6.21532696e-01
#   6.21557389e-01  6.23053307e-01  6.24045995e-01  6.25563108e-01
#   6.26200787e-01  6.27564069e-01  6.29902138e-01  6.31135647e-01
#   6.33311810e-01  6.35367861e-01  6.36156541e-01  6.36914659e-01
#   6.37200007e-01  6.37670996e-01  6.40667950e-01  6.45619899e-01
#   6.47196705e-01  6.47771916e-01  6.47897472e-01  6.48422828e-01
#   6.51191424e-01  6.52198632e-01  6.52836031e-01  6.53968564e-01
#   6.55049726e-01  6.55449488e-01  6.55623762e-01  6.55899605e-01
#   6.56564404e-01  6.57180574e-01  6.57197829e-01  6.62496222e-01
#   6.62899350e-01  6.63715308e-01  6.64300349e-01  6.65567647e-01
#   6.65987635e-01  6.66351541e-01  6.68874454e-01  6.68891257e-01
#   6.69675761e-01  6.70876720e-01  6.72786617e-01  6.73115188e-01
#   6.77073310e-01  6.77978829e-01  6.80372265e-01  6.81293668e-01
#   6.82769641e-01  6.84299428e-01  6.84999939e-01  6.85500130e-01
#   6.86200081e-01  6.86577647e-01  6.87035272e-01  6.87823480e-01
#   6.87999889e-01  6.88044119e-01  6.88299637e-01  6.88360330e-01
#   6.89299935e-01  6.89798374e-01  6.90953643e-01  6.92157355e-01
#   6.94271183e-01  6.96549386e-01  6.97906567e-01  6.99777393e-01
#   7.01373266e-01  7.02162623e-01  7.03893930e-01  7.04219057e-01
#   7.04982825e-01  7.06831505e-01  7.06915627e-01  7.07985995e-01
#   7.08982105e-01  7.09695871e-01  7.09968028e-01  7.11669161e-01
#   7.12207339e-01  7.12942704e-01  7.12994954e-01  7.13200221e-01
#   7.14549748e-01  7.18037343e-01  7.20488681e-01  7.22314721e-01
#   7.22926626e-01  7.24699399e-01  7.24847329e-01  7.25075619e-01
#   7.25657692e-01  7.25716599e-01  7.26780370e-01  7.26906860e-01
#   7.27401518e-01  7.27723890e-01  7.29106732e-01  7.29735442e-01
#   7.31007276e-01  7.31133181e-01  7.33191401e-01  7.33843952e-01
#   7.37499763e-01  7.37999905e-01  7.38799639e-01  7.40147238e-01
#   7.40601682e-01  7.40606469e-01  7.42239491e-01  7.42409401e-01
#   7.43719055e-01  7.48013563e-01  7.48397085e-01  7.48797393e-01
#   7.49545591e-01  7.49657569e-01  7.49852879e-01  7.53483752e-01
#   7.54173353e-01  7.54496594e-01  7.57138405e-01  7.57818915e-01
#   7.59515136e-01  7.62603942e-01  7.63096104e-01  7.64713003e-01
#   7.64738218e-01  7.65299883e-01  7.65800089e-01  7.70576692e-01
#   7.71296113e-01  7.71599711e-01  7.75054101e-01  7.76454933e-01
#   7.77285361e-01  7.78067636e-01  7.78501482e-01  7.79298814e-01
#   7.81697765e-01  7.81943039e-01  7.82681043e-01  7.82759860e-01
#   7.83995734e-01  7.86139608e-01  7.87455822e-01  7.88721207e-01
#   7.90697005e-01  7.90699990e-01  7.91457891e-01  7.92636151e-01
#   7.92961629e-01  7.94383572e-01  7.94437812e-01  7.97673827e-01
#   7.98294098e-01  8.01684597e-01  8.02672185e-01  8.03799856e-01
#   8.04299256e-01  8.04763170e-01  8.05198562e-01  8.06279921e-01
#   8.08000118e-01  8.08123871e-01  8.08136383e-01  8.09097673e-01
#   8.10458004e-01  8.14100086e-01  8.14600417e-01  8.14629540e-01
#   8.16160849e-01  8.16457151e-01  8.19300010e-01  8.19360392e-01
#   8.19399803e-01  8.20700781e-01  8.21235572e-01  8.21320957e-01
#   8.21399879e-01  8.22795453e-01  8.23194285e-01  8.23548204e-01
#   8.25174014e-01  8.25796574e-01  8.27194875e-01  8.27677126e-01
#   8.28791536e-01  8.29799951e-01  8.30587445e-01  8.30798975e-01
#   8.32554588e-01  8.33062836e-01  8.33834490e-01  8.34299610e-01
#   8.35003925e-01  8.35235564e-01  8.35334750e-01  8.35467427e-01
#   8.35545896e-01  8.37800080e-01  8.39603937e-01  8.41920849e-01
#   8.43960326e-01  8.45228363e-01  8.46060853e-01  8.46099900e-01
#   8.51537146e-01  8.51699990e-01  8.53399949e-01  8.53901173e-01
#   8.55449271e-01  8.56927532e-01  8.56983518e-01  8.60119166e-01
#   8.61200029e-01  8.65299759e-01  8.66465030e-01  8.69501315e-01
#   8.72530501e-01  8.73249089e-01  8.73398749e-01  8.75599938e-01
#   8.77697006e-01  8.78800993e-01  8.78806167e-01  8.82164972e-01
#   8.84302719e-01  8.86198139e-01  8.88220603e-01  8.88341443e-01
#   8.89199804e-01  8.90201145e-01  8.90209564e-01  8.90701488e-01
#   8.90795961e-01  8.92227994e-01  8.92280771e-01  8.95402188e-01
#   8.95803014e-01  8.96500036e-01  9.00306301e-01  9.02451312e-01
#   9.03432942e-01  9.04099193e-01  9.08200107e-01  9.08590062e-01
#   9.16565546e-01  9.18333880e-01  9.20700109e-01  9.22900122e-01
#   9.23120029e-01  9.23141366e-01  9.26199974e-01  9.26413231e-01
#   9.27036126e-01  9.35227063e-01  9.36861507e-01  9.38475126e-01
#   9.38864514e-01  9.42556735e-01  9.46010239e-01  9.48300655e-01
#   9.48599741e-01  9.53985121e-01  9.54569533e-01  9.56297632e-01
#   9.62114788e-01  9.63230890e-01  9.66396180e-01  9.71406215e-01
#   9.75990430e-01  9.83170797e-01  9.84016757e-01  9.84300484e-01
#   9.87234865e-01  9.88423422e-01  9.88910341e-01  9.93214593e-01
#   9.94281008e-01  9.94500452e-01  9.94999955e-01  9.96899747e-01
#   9.98685028e-01  1.00704391e+00  1.01122655e+00  1.01871751e+00
#   1.02080779e+00  1.02241815e+00  1.02331111e+00  1.02676154e+00
#   1.03839638e+00  1.04330001e+00  1.04606365e+00  1.05739983e+00
#   1.05803860e+00  1.06282479e+00  1.06500062e+00  1.06749168e+00
#   1.06759947e+00  1.07309952e+00  1.07739141e+00  1.08459995e+00
#   1.08595123e+00  1.09022642e+00  1.09172438e+00  1.09534757e+00
#   1.09676226e+00  1.09821449e+00  1.09897713e+00  1.09916519e+00
#   1.10640261e+00  1.10665868e+00  1.11370502e+00  1.11545865e+00
#   1.11991986e+00  1.12031659e+00  1.12738666e+00  1.13340101e+00
#   1.13767852e+00  1.13782312e+00  1.15031406e+00  1.15450011e+00
#   1.15621469e+00  1.15815617e+00  1.16304316e+00  1.16658585e+00
#   1.17290684e+00  1.18162521e+00  1.18754899e+00  1.19430205e+00
#   1.20335941e+00  1.20482117e+00  1.21200851e+00  1.21383997e+00
#   1.21841425e+00  1.21936314e+00  1.22140257e+00  1.22375177e+00
#   1.22822542e+00  1.23298827e+00  1.23350015e+00  1.26576944e+00
#   1.26963037e+00  1.27219782e+00  1.28137150e+00  1.31089534e+00
#   1.32375987e+00  1.32482221e+00  1.35218305e+00  1.37919742e+00
#   1.42059719e+00  1.46883001e+00  1.47486685e+00  1.48137589e+00
#   1.48792227e+00  1.49465025e+00  1.51398329e+00  1.52012072e+00
#   1.54268617e+00  1.56077774e+00  1.56305770e+00  1.62566483e+00
#   1.65344568e+00  1.65939948e+00  1.66479887e+00  1.67049474e+00
#   1.69999910e+00  1.75489076e+00  1.76292267e+00  1.77814716e+00]

# %%
fig=plt.figure(figsize=(8,8))
plt.scatter(movingmedian_f125_f160,movingmedian_f814_f125,c='gray',edgecolors='none',s=8,alpha=0.7)
plt.xlim(-0.5,4)
plt.ylim(-0.5,4)
plt.xlabel('J (1.25micron) - H (1.60micron)')
plt.ylabel('I (.814micron) - J (1.25micron)')
plt.savefig('/Users/Andy/Desktop/IJH_pt4_full_starlike_movingmedian.pdf')

# %%
fig=plt.figure(figsize=(8,8))
plt.scatter(f125_f160_egs,f814_f125_egs,c='gray',edgecolors='none',s=8,alpha=0.7)
plt.xlim(-0.5,4)
plt.ylim(-0.5,4)
plt.xlabel('J (1.25micron) - H (1.60micron)')
plt.ylabel('I (.814micron) - J (1.25micron)')
plt.savefig('/Users/Andy/Desktop/IJH_pt4_egs_starlike.pdf')

# %%
data = [x for _,x in sorted(zip(f814_f125_gds,f125_f160_gds))]
f814_f125_gds = np.sort(f814_f125_gds)
movingmedian_f814_f125_gds = np.array([])
movingmedian_f125_f160_gds = np.array([])
for i in range (0,200):
    data2 = np.array([])
    for j in range(i,i+15):
        data2 = np.append(data2,f814_f125_gds[j])
    movingmedian_f814_f125_gds = np.append(movingmedian_f814_f125_gds,np.median(data2))
for k in range (0,200):
    data3 = np.array([])
    for l in range(k,k+15):
        data3 = np.append(data3,f125_f160_gds[l])
    movingmedian_f125_f160_gds = np.append(movingmedian_f125_f160_gds,np.median(data3))

# %%
fig=plt.figure(figsize=(8,8))
plt.scatter(movingmedian_f125_f160_gds,movingmedian_f814_f125_gds,c='gray',edgecolors='none',s=8,alpha=0.7)
plt.xlim(-0.5,4)
plt.ylim(-0.5,4)
plt.xlabel('J (1.25micron) - H (1.60micron)')
plt.ylabel('I (.814micron) - J (1.25micron)')
plt.savefig('/Users/Andy/Desktop/IJH_pt4_gds_starlike_movingmedian.pdf')

# %%
fig=plt.figure(figsize=(8,8))
plt.scatter(f125_f160_gdn,f814_f125_gdn,c='gray',edgecolors='none',s=8,alpha=0.7)
plt.xlim(-0.5,4)
plt.ylim(-0.5,4)
plt.xlabel('J (1.25micron) - H (1.60micron)')
plt.ylabel('I (.814micron) - J (1.25micron)')
plt.savefig('/Users/Andy/Desktop/IJH_pt4_gdn_starlike.pdf')

# %%
data = [x for _,x in sorted(zip(f814_f125_gdn,f125_f160_gdn))]
f814_f125_gdn = np.sort(f814_f125_gdn)
movingmedian_f814_f125_gdn = np.array([])
movingmedian_f125_f160_gdn = np.array([])
for i in range (0,190):
    data2 = np.array([])
    for j in range(i,i+15):
        data2 = np.append(data2,f814_f125_gdn[j])
    movingmedian_f814_f125_gdn = np.append(movingmedian_f814_f125_gdn,np.median(data2))
for k in range (0,190):
    data3 = np.array([])
    for l in range(k,k+15):
        data3 = np.append(data3,f125_f160_gdn[l])
    movingmedian_f125_f160_gdn = np.append(movingmedian_f125_f160_gdn,np.median(data3))

# %%
fig=plt.figure(figsize=(8,8))
plt.scatter(movingmedian_f125_f160_gdn,movingmedian_f814_f125_gdn,c='gray',edgecolors='none',s=8,alpha=0.7)
plt.xlim(-0.5,4)
plt.ylim(-0.5,4)
plt.xlabel('J (1.25micron) - H (1.60micron)')
plt.ylabel('I (.814micron) - J (1.25micron)')
plt.savefig('/Users/Andy/Desktop/IJH_pt4_gdn_starlike_movingmedian.pdf')

# %%
fig=plt.figure(figsize=(8,8))
plt.scatter(f125_f160_cos,f814_f125_cos,c='gray',edgecolors='none',s=8,alpha=0.7)
plt.xlim(-0.5,4)
plt.ylim(-0.5,4)
plt.xlabel('J (1.25micron) - H (1.60micron)')
plt.ylabel('I (.814micron) - J (1.25micron)')
plt.savefig('/Users/Andy/Desktop/IJH_pt4_cos_starlike.pdf')

# %%
data = [x for _,x in sorted(zip(f814_f125_cos,f125_f160_cos))]
f814_f125_cos = np.sort(f814_f125_cos)
movingmedian_f814_f125_cos = np.array([])
movingmedian_f125_f160_cos = np.array([])
for i in range (0,190):
    data2 = np.array([])
    for j in range(i,i+15):
        data2 = np.append(data2,f814_f125_cos[j])
    movingmedian_f814_f125_cos = np.append(movingmedian_f814_f125_cos,np.median(data2))
for k in range (0,190):
    data3 = np.array([])
    for l in range(k,k+15):
        data3 = np.append(data3,f125_f160_cos[l])
    movingmedian_f125_f160_cos = np.append(movingmedian_f125_f160_cos,np.median(data3))

# %%
fig=plt.figure(figsize=(8,8))
plt.scatter(movingmedian_f125_f160_cos,movingmedian_f814_f125_cos,c='gray',edgecolors='none',s=8,alpha=0.7)
plt.xlim(-0.5,4)
plt.ylim(-0.5,4)
plt.xlabel('J (1.25micron) - H (1.60micron)')
plt.ylabel('I (.814micron) - J (1.25micron)')
plt.savefig('/Users/Andy/Desktop/IJH_pt4_cos_starlike_movingmedian.pdf')
